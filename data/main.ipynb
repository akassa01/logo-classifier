# %% [markdown]
# <h1 style="margin-bottom: 5px;">Logo Classification</h1>
# <h5 style="margin-top: 0; margin-bottom: 10px">
# Artificial Neural Networks and Deep Learning D - Spring 2026<br>
# Arman Kassam, Justin Kong, Shadab Sharif, and Tevin Park
# </h5>
# Logos are powerful visual signals that shape brand perception, influencing recognition, trust, and consumer behavior. In this project, we leverage deep learning to analyze and classify brand logos, uncovering patterns that link visual design to industry identity. By combining computer vision with structured labeling, we aim to explore how effectively a model can infer a company’s sector purely from its logo.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import kagglehub
import os
import requests
from dotenv import load_dotenv

load_dotenv()
KAGGLE_API_TOKEN = os.getenv("KAGGLE_API_TOKEN")

# %%
from kagglehub import KaggleDatasetAdapter

df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "kkhandekar/popular-brand-logos-image-dataset",
    "LogoDatabase.csv" 
)

print(df.head())
# Out:
#               logoName                                     fileName
# 0              YouTube                             youtube-logo.png
# 1  YouTube icon vector                     YouTube-icon-400x400.png
# 2              YouTube           youtube-logo-preview-1-400x400.png
# 3         FC Barcelona                    new-fc-barcelona-logo.png
# 4              YouTube  youtube-eps-version-vector-logo-400x400.png
# 1481

# %%
for row in df.itertuples():
    logo_name = row.logoName
    image_name = row.fileName
# Out:
# Logo Name: YouTube, Image Name: youtube-logo.png
# Logo Name: YouTube icon vector, Image Name: YouTube-icon-400x400.png
# Logo Name: YouTube, Image Name: youtube-logo-preview-1-400x400.png
# Logo Name: FC Barcelona, Image Name: new-fc-barcelona-logo.png
# Logo Name: YouTube, Image Name: youtube-eps-version-vector-logo-400x400.png
# Logo Name: Google Trends, Image Name: google-trends-logo.png
# Logo Name: HRC (Honda Racing Corporation), Image Name: hrc-logo-preview-400x400.png
# Logo Name: Xiaomi, Image Name: xiaomi-logo-vector-download.jpg
# Logo Name: Bamboo Airways, Image Name: Bamboo-Airways-logo-vector.png
# Logo Name: YouTube, Image Name: youtube-logo-vector-400x400.png
# Logo Name: Philipp Plein, Image Name: philipp-plein-logo-01.png
# Logo Name: Juventus, Image Name: juventus-fc-logo-400x400.png
# Logo Name: Facebook Icon, Image Name: facebook-icon-preview-1-400x400.png
# Logo Name: Uber, Image Name: uber-logo-vector.png
# Logo Name: PayPal  SVG, Image Name: paypal-logo-svg.png
# Logo Name: Dumbo, Image Name: dumbo-vector-400x400.png
# Logo Name: FSC, Image Name: fsc-logo-vector-download-400x400.jpg
# Logo Name: Dragon Ball Z, Image Name: dragon-ball-z-eps-vector-logo-400x400.png
# Logo Name: Instagram, Image Name: instagram-logo-vector-download-400x400.jpg
# Logo Name: Disturbed, Image Name: disturbed-vector-logo-400x400.png
# Logo Name: New YouTube button, Image Name: youtube-button-vector-400x400.png
# Logo Name: Adidas Originals, Image Name: adidas-originals-logo-400x400.png
# Logo Name: YouTube, Image Name: youtube-logo-preview-400x400.png
# Logo Name: Google Home, Image Name: google-home-logo.png
# Logo Name: Honda “H” Black, Image Name: honda-h-black-logo-400x400.png
# Logo Name: Instagram, Image Name: instagram-icon-logo-vector-download-400x400.jpg
# Logo Name: Dolphin, Image Name: dolphin-vector-400x400.png
# Logo Name: WhatsApp, Image Name: whatsapp-logo-symbol-vector-400x400.png
# Logo Name: Triumph Motorcycles, Image Name: triumph-motorcycles-logo.png
# Logo Name: Depeche Mode, Image Name: depeche-mode-eps-vector-logo-400x400.png
# Logo Name: UEFA Euro 2020, Image Name: uefa-euro-2020-logo-512x512.png
# Logo Name: YouTube, Image Name: youtube-eps-vector-logo-400x400.png
# Logo Name: Google, Image Name: google-logo-400x400.png
# Logo Name: Facebook, Image Name: facebook-flat-vector-logo-400x400.png
# Logo Name: Honda Bike, Image Name: honda-bike-vector-400x400.jpg
# Logo Name: UPS (United Parcel Service), Image Name: ups-logo-vector-download-400x400.jpg
# Logo Name: YouTube, Image Name: youtube-vector-logo-400x400.png
# Logo Name: Disney’s High School Musical, Image Name: disneys-high-school-musical-vector-logo-400x400.png
# Logo Name: Facebook Workplace, Image Name: facebook-workplace-logo-preview-400x400.png
# Logo Name: Youtube Button, Image Name: youtube-button-logo-vector-400x400.png
# Logo Name: App Store, Image Name: apple-app-store-logo.png
# Logo Name: Instagram, Image Name: Instagram-logo-400x400.png
# Logo Name: Google Assistant, Image Name: google-assistant-logo.png
# Logo Name: Death Proof, Image Name: death-proof-vector-logo-400x400.png
# Logo Name: Dsquared2, Image Name: dsquared-logo-vector-400x400.png
# Logo Name: HONDA, Image Name: honda-3d-vector-logo-400x400.png
# Logo Name: Honda Civic, Image Name: honda-civic-logo.png
# Logo Name: Supreme, Image Name: supreme-logo.png
# Logo Name: Gmail, Image Name: google-mail-logo-vector-download-400x400.jpg
# Logo Name: Google Favicon, Image Name: google-favicon-vector-400x400.png
# Logo Name: Balenciaga, Image Name: balenciaga-vector-logo-400x400.png
# Logo Name: Nike, Image Name: nike-logo-vector-download-400x400.jpg
# Logo Name: Facebook Like, Image Name: Facebook-Like-400x400.png
# Logo Name: Deftones, Image Name: deftones-eps-vector-logo-400x400.png
# Logo Name: Christian Dior, Image Name: christian-dior-vector-400x400.jpg
# Logo Name: Google Calendar, Image Name: Google-Calendar-icon.png
# Logo Name: Minions, Image Name: minions-film-logo-400x400.png
# Logo Name: Spotify, Image Name: spotify-logo-400x400.png
# Logo Name: Get it on Google play, Image Name: get-it-on-google-play-vector-400x400.png
# Logo Name: Facebook, Image Name: facebook-logo-preview-400x400.png
# Logo Name: Uniqlo, Image Name: uniqlo-logo-preview-400x400.png
# Logo Name: Dream Theater, Image Name: dream-theater-eps-vector-logo-400x400.png
# Logo Name: Honda, Image Name: honda-logo-vector-download-400x400.jpg
# Logo Name: BMW, Image Name: bmw-flat-logo-vector-download-400x400.jpg
# Logo Name: Dai-ichi Hoki, Image Name: dai-ichi-hoki-vector-logo-400x400.png
# Logo Name: Chennai Super Kings, Image Name: chennai-super-kings-vector-logo-400x400.png
# Logo Name: Adidas Black, Image Name: adidas-black-vector-logo-400x400.png
# Logo Name: Escudo de la Republica Argentina, Image Name: escudo-de-la-republica-argentina-logo-vector-400x400.png
# Logo Name: Real Madrid C.F., Image Name: real-madrid-logo-preview-400x400.png
# Logo Name: GSK, Image Name: gsk-logo-vector-download-400x400.jpg
# Logo Name: Taobao, Image Name: taobao-logo-vector-download-400x400.jpg
# Logo Name: IKEA, Image Name: ikea-logo.png
# Logo Name: Get It On Google Play badge, Image Name: get-it-on-google-play-preview-400x400.png
# Logo Name: Facebook Live, Image Name: facebook-live-logo-vector-download-400x400.jpg
# Logo Name: Google Chrome, Image Name: google-chrome-logo-vector-download-400x400.jpg
# Logo Name: Toronto Raptors, Image Name: toronto-raptors-logo-preview-400x400.png
# Logo Name: Balmain, Image Name: Balmain-logo-400x400.png
# Logo Name: Honda, Image Name: honda-silver-logo-vector-400x400.png
# Logo Name: Foxtel, Image Name: foxtel-logo.png
# Logo Name: POSB, Image Name: POSB-Bank-logo-vector.png
# Logo Name: Johnnie Walker new, Image Name: johnnie-walker-logo-vector-download-400x400.jpg
# Logo Name: Nike symbol, Image Name: Nike-symbol-vector-400x400.png
# Logo Name: Porn star, Image Name: porn-star-vector-logo-400x400.png
# Logo Name: Disney Halloween, Image Name: disney-halloween-vector-logo-400x400.png
# Logo Name: Visa, Image Name: visa-logo-preview-400x400.png
# Logo Name: Travel Channel, Image Name: travel-channel-logo.png
# Logo Name: PlayStation 4 (PS4), Image Name: playstation-4-logo-01.png
# Logo Name: Wonder Woman, Image Name: wonder-woman-logo.png
# Logo Name: DC Comics, Image Name: dc-comics-logo-vector-download-400x400.jpg
# Logo Name: Discovery Kids, Image Name: discovery-kids-vector-logo-400x400.png
# Logo Name: Facebook icon circle, Image Name: facebook-icon-preview-400x400.png
# Logo Name: Telenor, Image Name: Telenor-logo-vector.png
# Logo Name: Le Coq Sportif, Image Name: le-coq-sportif-logo.png
# Logo Name: Domino’s Pizza, Image Name: dominos-pizza-logo.png
# Logo Name: Alipay, Image Name: alipay-logo.png
# Logo Name: Walt Disney, Image Name: walt-disney-logo-preview-400x400.png
# Logo Name: State Farm, Image Name: state-farm-logo-vector-400x400.png
# Logo Name: American Express, Image Name: american-express-logo.png
# Logo Name: WhatsApp, Image Name: whatsapp-icon-vector-400x400.png
# Logo Name: Karl Lagerfeld, Image Name: karl-lagerfeld-logo.png
# Logo Name: Monster Energy drink, Image Name: monster-energy-logo-vector-download-400x400.jpg
# Logo Name: Suzuki, Image Name: suzuki-eps-vector-logo-400x400.png
# Logo Name: Gucci, Image Name: gucci-logo-preview-400x400.png
# Logo Name: Toyota Landcruiser, Image Name: toyota-landcruiser-vector-logo-400x400.png
# Logo Name: On The App Store Flat Badge, Image Name: download-on-the-app-store-badge.png
# Logo Name: Nintendo Switch, Image Name: nintendo-switch-logo-preview-400x400.png
# Logo Name: KS Olimpia Lewin Brzeski, Image Name: ks-olimpia-lewin-brzeski-vector-logo-400x400.png
# Logo Name: Available At Amazon Badges, Image Name: Available-At-Amazon-400x400.png
# Logo Name: Paramount Network, Image Name: paramount-network-logo.png
# Logo Name: Destruction, Image Name: destruction-vector-logo-400x400.png
# Logo Name: Disneyland Park, Image Name: disneyland-park-vector-logo-400x400.png
# Logo Name: Moto Guzzi, Image Name: moto-guzzi-logo.png
# Logo Name: Michelin Tires, Image Name: michelin-tires-logo-vector-download-400x400.jpg
# Logo Name: Fox Racing, Image Name: fox-racing-vector-logo-400x400.png
# Logo Name: Jack Daniel’s, Image Name: jack-daniels-logo-400x400.png
# Logo Name: Android Pay logo SVG, Image Name: Google-Pay-logo-vector.png
# Logo Name: Dakar, Image Name: dakar-vector-logo-400x400.png
# Logo Name: Google, Image Name: google-logo-400x400.png
# Logo Name: Under Armour, Image Name: under-armour-black-logo.png
# Logo Name: Starbucks, Image Name: starbucks-logo-preview-400x400.png
# Logo Name: Manulife, Image Name: manulife-logo-preview-400x400.png
# Logo Name: Nike Swoosh, Image Name: nike-swoosh-vector-logo-400x400.png
# Logo Name: Dungeons & Dragons, Image Name: dungeons-dragons-vector-logo-400x400.png
# Logo Name: Mickey Mouse, Image Name: mickey-mouse-disney-vector-400x400.png
# Logo Name: Negara malaysia, Image Name: negara-malaysia-vector-logo-400x400.png
# Logo Name: Louis Vuitton, Image Name: Louis-Vuitton-vector-logo-download-400x400.png
# Logo Name: PayPal, Image Name: paypal-logo-preview-400x400.png
# Logo Name: Peugeot, Image Name: Peugeot-vector-logo-400x400.png
# Logo Name: Twitter, Image Name: twitter-square-logo-400x400.png
# Logo Name: Bindal Fotball, Image Name: bindal-fotball-vector-logo-400x400.png
# Logo Name: WhatsApp, Image Name: whatsapp-logo.png
# Logo Name: Google Drive, Image Name: google-drive-logo.png
# Logo Name: MasterCard, Image Name: mastercard-vector-logo-400x400.png
# Logo Name: WhatsApp, Image Name: whatsapp-vector-logo-400x400.png
# Logo Name: Social Network icons vector, Image Name: social-network-logo-vector-512x512.png
# Logo Name: MarketWatch, Image Name: marketwatch-logo-vector-download-400x400.png
# Logo Name: Renault, Image Name: new-renault-logo-vector-download-400x400.jpg
# Logo Name: Tom and Jerry, Image Name: tom-and-jerry-logo-vector-400x400.png
# Logo Name: Cobra Kai, Image Name: cobra-kai-vector-logo-400x400.png
# Logo Name: LKS Victoria Cisek, Image Name: lks-victoria-cisek-vector-logo-400x400.png
# Logo Name: Yves Saint Laurent, Image Name: yves-saint-laurent-logo-vector-400x400.png
# Logo Name: Facebook, Image Name: new-facebook-logo-2015-400x400.png
# Logo Name: LZS Parkowa Kantorowice, Image Name: lzs-parkowa-kantorowice-vector-logo-400x400.png
# Logo Name: LZS Burza Greboszow, Image Name: lzs-burza-greboszow-vector-logo-400x400.png
# Logo Name: Google Earth, Image Name: New-Google-Earth-logo.png
# Logo Name: SOFORT, Image Name: sofort-logo.png
# Logo Name: Spiderman, Image Name: spiderman-symbol-vector-logo-400x400.png
# Logo Name: KS Gornik, Image Name: ks-gornik-occasional-vector-logo-400x400.png
# Logo Name: LinkedIn icon, Image Name: linkedin-logo-vector-download-400x400.jpg
# Logo Name: KS Czarni Jaworze, Image Name: ks-czarni-jaworze-vector-logo-400x400.png
# Logo Name: Nike Just Do It, Image Name: nike-just-do-it-vector-logo-400x400.png
# Logo Name: Mazda Skyactiv, Image Name: mazda-skyactiv-logo-vector-download-400x400.jpg
# Logo Name: LKS Tecza Ojrzen, Image Name: lks-tecza-ojrzen-vector-logo-400x400.png
# Logo Name: Mickey Mouse, Image Name: Mickey-Mouse-vector.png
# Logo Name: Walmart Spark, Image Name: walmart-logo-preview-400x400.png
# Logo Name: Daddy Yankee, Image Name: daddy-yankee-vector-logo-400x400.png
# Logo Name: Bon FK, Image Name: bon-fk-vector-logo-400x400.png
# Logo Name: Spotify, Image Name: spotify-logo-vector-download.jpg
# Logo Name: Billabong, Image Name: billabong-logo.png
# Logo Name: Versace Jeans Couture, Image Name: versace-jeans-couture-logo-preview-400x400.png
# Logo Name: Honda CRV, Image Name: honda-crv-logo.png
# Logo Name: Godaddy, Image Name: GoDaddy-logo-vector.png
# Logo Name: GKS Piast Gliwice, Image Name: gks-piast-gliwice-lat-vector-logo-400x400.png
# Logo Name: Polski Zwiazek Pilki Noznej, Image Name: polski-zwiazek-pilki-noznej-polska-2011-vector-logo-400x400.png
# Logo Name: Mazda CX-5, Image Name: mazda-cx-5-logo-vector-download-400x400.jpg
# Logo Name: Available on the App Store, Image Name: available-on-the-app-store-400x400.png
# Logo Name: GKS Jastrzebie, Image Name: gks-jastrzebie-vector-logo-400x400.png
# Logo Name: Coat of arms of Malaysia, Image Name: coat-of-arms-of-malaysia-vector-logo-400x400.png
# Logo Name: Clube de Regatas do Flamengo 2001-2004, Image Name: clube-de-regatas-do-flamengo-2001-2004-logo-vector-400x400.png
# Logo Name: Honda’s Certified, Image Name: hondas-certified-vector-preview-400x400.png
# Logo Name: Depeche Mode (DM), Image Name: depeche-mode-dm-vector-logo-400x400.png
# Logo Name: KS Gornik, Image Name: ks-gornik-old-vector-logo-400x400.png
# Logo Name: Google Chrome, Image Name: Google-Chrome-logo-vector-download.png
# Logo Name: Calvin Klein, Image Name: calvin-klein-.eps-logo-vector-400x400.png
# Logo Name: Copyright, Image Name: Copyright-symbol-vector-free-download.png
# Logo Name: Cork City FC, Image Name: cork-city-fc-current-vector-logo-400x400.png
# Logo Name: Mailchimp, Image Name: Mailchimp-logo-2018.png
# Logo Name: Liverpool, Image Name: liverpool-logo-vector-400x400.png
# Logo Name: LKS Plon Skoroszyce, Image Name: lks-plon-skoroszyce-vector-logo-400x400.png
# Logo Name: AC Cuneo 1905, Image Name: ac-cuneo-1905-vector-logo-400x400.png
# Logo Name: Toyota, Image Name: toyota-logo-vector-download-400x400.jpg
# Logo Name: OPPO, Image Name: oppo-smartphone-logo-seeklogo-400x400.png
# Logo Name: Booking.com, Image Name: bookingcom-logo-vector-download-400x400.jpg
# Logo Name: Google Pay, Image Name: Google-Pay-logo-vector.png
# Logo Name: Google Play 2015, Image Name: google-play-2015-logo-vector-download-400x400.jpg
# Logo Name: Asane Fotball, Image Name: asane-fotball-vector-logo-400x400.png
# Logo Name: Avaldsnes IL, Image Name: avaldsnes-il-vector-logo-400x400.png
# Logo Name: KS Unia Tulowice, Image Name: ks-unia-tulowice-1905-vector-logo-400x400.png
# Logo Name: Adidas, Image Name: adidas-3-vector-logo-400x400.png
# Logo Name: Ducati Scrambler, Image Name: ducati-scrambler-logo.png
# Logo Name: VV Smitshoek, Image Name: vv-smitshoek-vector-logo-400x400.png
# Logo Name: Instagram icon Circle, Image Name: instagram-icon-circle-vector-logo-400x400.png
# Logo Name: Android app on Google play, Image Name: Android-app-on-Google-play-badge-vector.png
# Logo Name: Disneyland, Image Name: disneyland-vector-logo-400x400.png
# Logo Name: Ferrari, Image Name: ferrari-logo.png
# Logo Name: Mercedes-Benz, Image Name: mercedes-benz-logo-vector-download-400x400.jpg
# Logo Name: Bray Wanderers AFC, Image Name: bray-wanderers-afc-vector-logo-400x400.png
# Logo Name: Abu Dhabi, Image Name: abu-dhabi-logo.png
# Logo Name: Coca-cola, Image Name: coca-cola-logo-400x400.png
# Logo Name: Anker, Image Name: anker-logo-vector-download-400x400.png
# Logo Name: Puma, Image Name: Puma-logo-400x400.png
# Logo Name: VANS, Image Name: vans-logo.png
# Logo Name: Evernote, Image Name: evernote-new-logo-2018.png
# Logo Name: RKS Mirkow, Image Name: rks-mirkow-vector-logo-400x400.png
# Logo Name: Amazon, Image Name: amazon-logo-preview-400x400.png
# Logo Name: Microsoft Office 365, Image Name: office-365-logo-400x400.png
# Logo Name: Danger Mouse, Image Name: danger-mouse-eps-vector-logo-400x400.png
# Logo Name: Drogheda United FC, Image Name: drogheda-united-fc-old-vector-logo-400x400.png
# Logo Name: Facebook Emoticons, Image Name: facebook-emoticons-preview-400x400.png
# Logo Name: Lamborghini, Image Name: lamborghini-logo.png
# Logo Name: Motul, Image Name: motul-logo-vector-01.png
# Logo Name: Twitter Icon Circle (Blue), Image Name: twitter-icon-circle-blue-logo-preview-400x400.png
# Logo Name: IL Sandviken, Image Name: il-sandviken-vector-logo-400x400.png
# Logo Name: Chanel, Image Name: chanel-logo-vector-400x400.png
# Logo Name: Chiquita, Image Name: chiquita-logo.png
# Logo Name: LKS Gron Bujakow, Image Name: lks-gron-bujakow-vector-logo-400x400.png
# Logo Name: KP Unia Raciborz, Image Name: kp-unia-raciborz-vector-logo-400x400.png
# Logo Name: Abercrombie & Fitch, Image Name: abercrombie-and-fitch-black-vector-logo-400x400.png
# Logo Name: Motul, Image Name: motul-company-vector-logo-400x400.png
# Logo Name: Mercedes Benz, Image Name: Mercedes-Benz-logo-vector-free-download.png
# Logo Name: Yoshimura, Image Name: yoshimura-vector-logo-400x400.png
# Logo Name: Rammstein, Image Name: rammstein-vector-logo-400x400.png
# Logo Name: Nike Classic, Image Name: nike-classic-vector-logo-400x400.png
# Logo Name: Cork City FC, Image Name: cork-city-fc-old-2007-vector-logo-400x400.png
# Logo Name: Metallica, Image Name: metallica-9-vector-logo-400x400.png
# Logo Name: Netflix, Image Name: netflix-logo-vector-400x400.png
# Logo Name: Everton Football Club, Image Name: everton-football-club-logo-preview-400x400.png
# Logo Name: FIFA, Image Name: fifa-logo-vector-download-400x400.jpg
# Logo Name: Bootstrap, Image Name: bootstrap-logo-vector-download-400x400.jpg
# Logo Name: LZS Wojcice, Image Name: lzs-wojcice-vector-logo-400x400.png
# Logo Name: BMW, Image Name: bmw-vector-logo-400x400.png
# Logo Name: Burberry, Image Name: Burberry-logo-vector-.png
# Logo Name: Zara, Image Name: zara-logo-preview-400x400.png
# Logo Name: LKS Grapa Trzebinia, Image Name: lks-grapa-trzebinia-vector-logo-400x400.png
# Logo Name: Cork City FORAS Co-op, Image Name: cork-city-foras-co-op-old-vector-logo-400x400.png
# Logo Name: UPS, Image Name: new-ups-logo-vector-download.jpg
# Logo Name: TaylorMade Golf, Image Name: taylormade-logo-preview-400x400.png
# Logo Name: DreamWorks Home Entertainment, Image Name: dreamworks-home-entertainment-vector-logo-400x400.png
# Logo Name: Polski Zwiazek Pilki Noznej, Image Name: polski-zwiazek-pilki-noznej-polska-vector-logo-400x400.png
# Logo Name: Cork City FC, Image Name: cork-city-fc-old-vector-logo-400x400.png
# Logo Name: Nike SB, Image Name: nike-sb-vector-logo-400x400.png
# Logo Name: Suzuki, Image Name: suzuki-logo-1.png
# Logo Name: Diga nao As Drogas, Image Name: diga-nro-аs-drogas.png
# Logo Name: RB Leipzig, Image Name: rb-leipzig-logo-preview-400x400.png
# Logo Name: AFC Champions League, Image Name: afc-champions-league-logo.png
# Logo Name: EA7 Emporio Armani, Image Name: ea7-emporio-armani-vector-logo-400x400.png
# Logo Name: Johnnie Walker “Keep Walking”, Image Name: johnnie-walker-logo-400x400.png
# Logo Name: Twitter Icon Circle, Image Name: twitter-icon-circle-logo-400x400.png
# Logo Name: Avengers, Image Name: avengers-logo-400x400.png
# Logo Name: Instagram icon, Image Name: Instagram-icon-400x400.png
# Logo Name: Audi Quattro, Image Name: audi-quattro-vector-logo-400x400.png
# Logo Name: Dallas Cowboys Helmet, Image Name: dallas-cowboys-helmet-400x400.png
# Logo Name: Twitter Icon Square, Image Name: twitter-icon-square-logo-preview-400x400.png
# Logo Name: Red Bull, Image Name: red-bull-logo-vector-download-400x400.jpg
# Logo Name: QBE Insurance, Image Name: qbe-insurance-logo.png
# Logo Name: Under Armour, Image Name: under-armour-eps-ai.png
# Logo Name: Vimeo, Image Name: vimeo-icon-vector-400x400.png
# Logo Name: Unicef, Image Name: unicef-cyan-vector-logo-400x400.png
# Logo Name: Skechers, Image Name: skechers-logo-preview-400x400.png
# Logo Name: Samsung, Image Name: samsung-logo-preview-400x400.png
# Logo Name: Tesla, Image Name: tesla-logo-vector-download-400x400.jpg
# Logo Name: Hot Wheels, Image Name: hot-wheels-logo.png
# Logo Name: Renault auto, Image Name: renault-auto-vector-logo-400x400.png
# Logo Name: Find Us On Facebook, Image Name: find-us-on-facebook-Badge-vector-download-400x400.jpg
# Logo Name: Visa, Image Name: visa-logo-400x400.png
# Logo Name: Juventus, Image Name: juventus-fc-logo-400x400.png
# Logo Name: Levis, Image Name: levis-vector-logo-400x400.png
# Logo Name: Taco Bell new, Image Name: taco-bell-logo-preview-400x400.png
# Logo Name: Jeep, Image Name: jeep-new-vector-logo-400x400.png
# Logo Name: HP, Image Name: hp-eps-vector-logo-400x400.png
# Logo Name: GKS Belchatow, Image Name: gks-belchatow-vector-logo-400x400.png
# Logo Name: Mazda, Image Name: mazda-black-vector-logo-400x400.png
# Logo Name: Techcombank, Image Name: techcombank-logo-preview-400x400.png
# Logo Name: Atari, Image Name: atari-black-vector-logo-400x400.png
# Logo Name: Nike, Inc, Image Name: nike-inc-eps-vector-logo-400x400.png
# Logo Name: Mercedes-Benz, Image Name: mercedes-benz-auto-eps-vector-logo-400x400.png
# Logo Name: Superman, Image Name: superman-s-vector-logo-400x400.png
# Logo Name: Guns N’ Roses, Image Name: Guns-N-Roses-logo-400x400.png
# Logo Name: BMW Mini Cooper, Image Name: bmw-mini-cooper-logo-vector-01.png
# Logo Name: LKS Huragan Kocikowa, Image Name: lks-huragan-kocikowa-vector-logo-400x400.png
# Logo Name: Mazda CX-3, Image Name: mazda-cx-3-logo-vector-download-400x400.jpg
# Logo Name: Harman, Image Name: harman-logo-preview-400x400.png
# Logo Name: Continental Tires, Image Name: continental-tires-logo-vector-download-400x400.jpg
# Logo Name: Ducati, Image Name: ducati-logo-vector-download-1-400x400.jpg
# Logo Name: Mercedes-Benz, Image Name: mercedes-benz-vector-logo-400x400.png
# Logo Name: Escudo de Venezuela, Image Name: escudo-de-venezuela-logo-vector-400x400.png
# Logo Name: Allegiant Air (.EPS + AI), Image Name: allegiant-air-logo-preview-400x400.png
# Logo Name: KS Unia Tulowice, Image Name: ks-unia-tulowice-vector-logo-400x400.png
# Logo Name: Nirvana, Image Name: Nirvana-logo-png-400x400.png
# Logo Name: Louis Vuitton, Image Name: louis-vuitton-eps-vector-logo-400x400.png
# Logo Name: Facebook Messenger, Image Name: facebook-messenger-logo-preview-400x400.png
# Logo Name: Reebok, Image Name: reebok-vector-logo-400x400.png
# Logo Name: Renault, Image Name: renault-logo-vector-400x400.png
# Logo Name: Yapi Kredi World Card, Image Name: yapi-kredi-world-card-vector-logo-400x400.png
# Logo Name: Shopifymark, Image Name: shopify-logomark-logo.png
# Logo Name: Facebook Messenger, Image Name: facebook-messenger-logo-preview-400x400.png
# Logo Name: LKS Krokus Przyszowa, Image Name: lks-krokus-przyszowa-vector-logo-400x400.png
# Logo Name: Rakuten, Image Name: rakuten-logo.png
# Logo Name: SpiderMan, Image Name: spider-man-logo-vector-400x400.png
# Logo Name: Caterpillar, Image Name: caterpillar-.eps-logo-vector-400x400.png
# Logo Name: Dora, Image Name: dora-logo-vector-400x400.png
# Logo Name: AC Milan, Image Name: ac-milan-eps-vector-logo-400x400.png
# Logo Name: DPD (Dynamic Parcel Distribution), Image Name: dpd-vector-logo-400x400.png
# Logo Name: MIT, Image Name: mit-logo-vector-download-400x400.jpg
# Logo Name: Airtel 2010, Image Name: airtel-2010-vector-logo-400x400.png
# Logo Name: GKS Odra Wodzislaw Slaski, Image Name: gks-odra-wodzislaw-slaski-vector-logo-400x400.png
# Logo Name: SHARK Energy, Image Name: shark-energy-logo-preview-400x400.png
# Logo Name: Yamaha, Image Name: yamaha-old-vector-logo-400x400.png
# Logo Name: Escudo de Estados Unidos Mexicanos, Image Name: escudo-de-estados-unidos-mexicanos-logo-vector-400x400.png
# Logo Name: Toyota Flat, Image Name: toyota-flat-logo-vector-download-400x400.jpg
# Logo Name: WHO, Image Name: who-logo-vector.png
# Logo Name: Repsol, Image Name: repsol-motor-vector-logo-400x400.png
# Logo Name: Mazda Motor, Image Name: mazda-logo-vector-download-400x400.jpg
# Logo Name: Escudo Nacional Mexicano, Image Name: escudo-nacional-mexicano-logo-vector-400x400.png
# Logo Name: UEFA Champions League, Image Name: uefa-champions-league-eps-vector-logo-400x400.png
# Logo Name: DSTV, Image Name: dstv-vector-logo-400x400.png
# Logo Name: Aston Martin, Image Name: aston-martin-logo-preview-400x400.png
# Logo Name: UEFA Super Cup, Image Name: uefa-super-cup-logo.png
# Logo Name: DKSH, Image Name: dksh-logo-preview-400x400.png
# Logo Name: My fish, Image Name: my-fish-vector-logo-400x400.png
# Logo Name: Pokémon Go, Image Name: pokemon-go-vector-logo-400x400.png
# Logo Name: Chevy Racing, Image Name: chevy-racing-logo-vector-400x400.png
# Logo Name: Polski Zwiazek Pilki Noznej, Image Name: polski-zwiazek-pilki-noznej-pzpn-vector-logo-400x400.png
# Logo Name: Find Us on Facebook Badge, Image Name: find-us-on-facebook-badge-400x400.png
# Logo Name: New Disney Channel, Image Name: new-disney-channel-logo.png
# Logo Name: New Balance, Image Name: new-balance-black-vector-logo-400x400.png
# Logo Name: Instagram, Image Name: new-instagram-logo-seeklogo.net_-400x400.png
# Logo Name: Snapchat, Image Name: snapchat-logo-preview-400x400.png
# Logo Name: Commonwealth Bank, Image Name: commonwealth-bank-2013-vector-logo-400x400.png
# Logo Name: Chevrolet, Image Name: chevrolet-logo.png
# Logo Name: USAA, Image Name: usaa-logo.png
# Logo Name: Converse All Star, Image Name: converse-all-star-.eps-logo-vector-400x400.png
# Logo Name: PTC, Image Name: ptc-logo.png
# Logo Name: Nissan, Image Name: nissan-logo-preview-400x400.png
# Logo Name: Gloria Jean’s Coffees, Image Name: gloria-jeans-coffees-logo-vector-download-400x400.jpg
# Logo Name: Coors Light, Image Name: coors-light-logo.png
# Logo Name: Vodafone, Image Name: vodafone-logo.png
# Logo Name: Samsung Group, Image Name: samsung-group-vector-logo-400x400.png
# Logo Name: LG Life’s Good, Image Name: lg-lifes-good-eps-vector-logo-400x400.png
# Logo Name: Queen, Image Name: queen-eps-vector-logo-400x400.png
# Logo Name: Michelin, Image Name: michelin-logo-vector-download-400x400.jpg
# Logo Name: Emblem of India, Image Name: emblem-of-india-logo-vector-400x400.png
# Logo Name: The Grinch, Image Name: the-grinch-vector-400x400.png
# Logo Name: UEFA Champions League, Image Name: uefa-champions-league-logo.png
# Logo Name: Mickey Mouse, Image Name: mickey-mouse-eps-vector-400x400.png
# Logo Name: ImLive.com, Image Name: imlive-vector-logo-400x400.png
# Logo Name: Bob marley, Image Name: bob-marley-logo-vector-400x400.png
# Logo Name: Lilo & Stitch, Image Name: lilo-stitch-vector-400x400.png
# Logo Name: Transformers, Image Name: transformers-movies-vector-logo-400x400.png
# Logo Name: Spirit Airlines, Image Name: spirit-airlines-logo-preview-400x400.png
# Logo Name: EBay Store, Image Name: ebay-store-logo-vector-download-400x400.jpg
# Logo Name: Bosch, Image Name: bosch-logo-vector-download-400x400.jpg
# Logo Name: Renault, Image Name: renault-old-1992-vector-logo-400x400.png
# Logo Name: Beyblade, Image Name: beyblade-vector-logo-400x400.png
# Logo Name: Listen on Apple Music Badge, Image Name: listen-on-apple-music-badge-400x400.png
# Logo Name: Kit Kat, Image Name: kit-kat-logo-vector-400x400.png
# Logo Name: iPhone 6s, Image Name: apple-iphone-6s-logo-vector-download-400x400.jpg
# Logo Name: Oriflame Cosmetics, Image Name: oriflame-cosmetics-vector-logo-400x400.png
# Logo Name: Arsenal, Image Name: arsenal-fc-logo.png
# Logo Name: Western Union, Image Name: western-union-logo-vector-download-1-400x400.jpg
# Logo Name: Mazinger Z, Image Name: mazinger-z-vector-400x400.png
# Logo Name: Adidas, Image Name: Adidas-logo-400x400.png
# Logo Name: Chelsea, Image Name: chelsea-logo-vector-400x400.png
# Logo Name: Ford, Image Name: ford-logo.png
# Logo Name: Twitter, Image Name: Twitter-logo-vector.png
# Logo Name: Petrolimex, Image Name: petrolimex-logo-vector-download-400x400.jpg
# Logo Name: Minnie Mouse, Image Name: minnie-mouse-eps-vector-400x400.png
# Logo Name: Kawasaki, Image Name: kawasaki-logo-01.png
# Logo Name: Unilever, Image Name: unilever-logo-01.png
# Logo Name: Tesla, Image Name: tesla-vector-logo-400x400.png
# Logo Name: Depeche Mode Music, Image Name: depeche-mode-music-vector-logo-400x400.png
# Logo Name: KIA Motors, Image Name: kia-motors-logo-vector-400x400.png
# Logo Name: Audi, Image Name: audi-logo-vector-download-400x400.jpg
# Logo Name: Medicine, Image Name: medicine-vector-logo-400x400.png
# Logo Name: Polski Zwiazek Pilki Noznej, Image Name: polski-zwiazek-pilki-noznej-2011-vector-logo-400x400.png
# Logo Name: Mastercard Maestro, Image Name: mastercard-maestro-logo-vector-400x400.png
# Logo Name: Porsche, Image Name: Porsche-logo-01.png
# Logo Name: M&M’s, Image Name: mms-vector-400x400.jpg
# Logo Name: Tiger Beer, Image Name: tiger-beer-logo-512x512.png
# Logo Name: Android, Image Name: android-vector-logo.png
# Logo Name: Paris Saint-Germain FC, Image Name: new-Paris-Saint-Germain-seeklogo-12072015-400x400.png
# Logo Name: Hollister California, Image Name: hollister-vector-logo-400x400.png
# Logo Name: Spiderman, Image Name: Spiderman-vector-logo-400x400.png
# Logo Name: Subway, Image Name: subway-logo-preview-400x400.jpg
# Logo Name: xXx, Image Name: xxx-logo-vector-01-400x400.png
# Logo Name: Applied Materials, Image Name: applied-materials-logo-vector-download-400x400.jpg
# Logo Name: Triumph, Image Name: triumph-moto-vector-logo-400x400.png
# Logo Name: New Samuel Adams, Image Name: samuel-adams-logo-preview-400x400.png
# Logo Name: Pauta Musica, Image Name: pauta-musica-vector-400x400.png
# Logo Name: West Ham United FC, Image Name: west-ham-united-fc-logo-preview-400x400.png
# Logo Name: Chicago Bulls, Image Name: chicago-bulls-logo-preview-400x400.png
# Logo Name: Google Play Music, Image Name: google-play-music-logo-400x400.png
# Logo Name: AT&T, Image Name: at-t-logo.png
# Logo Name: Yamaha R1, Image Name: Yamaha-R1-logo-400x400.jpg
# Logo Name: DELL 2016, Image Name: dell-logo-preview-400x400.png
# Logo Name: Find us on Facebook, Image Name: find-us-on-facebook-logo-vector-400x400.png
# Logo Name: Heineken, Image Name: Heineken-logo-400x400.png
# Logo Name: New Calvin Klein, Image Name: calvin-klein-logo.png
# Logo Name: Paris FC, Image Name: paris-fc-1969-vector-logo-400x400.png
# Logo Name: LinkedIn, Image Name: linkedin-logo-512x512.png
# Logo Name: Givenchy Paris, Image Name: givenchy-paris-logo-vector-400x400.png
# Logo Name: Escudo Nacional, Image Name: escudo-nacional-logo-vector-400x400.png
# Logo Name: Harley-Davidson Cycles, Image Name: harley-davidson-cycles-logo-vector-400x400.png
# Logo Name: Brembo, Image Name: brembo-logo-vector-01.png
# Logo Name: Mercedes-Benz, Image Name: mercedes-benz-auto-vector-logo1-400x400.png
# Logo Name: NASCAR, Image Name: nascar-logo-400x400.png
# Logo Name: Apple iPhone 6S, Image Name: iphone-6s-logo-vector-download-400x400.jpg
# Logo Name: Reliance Industries Limited, Image Name: reliance-industries-limited-vector-logo-400x400.png
# Logo Name: Nestle, Image Name: nestle-sa-vector-logo-400x400.png
# Logo Name: H&M, Image Name: h-m-logo-400x400.png
# Logo Name: Vans red scuares, Image Name: vans-red-scuares-vector-logo-400x400.png
# Logo Name: FK Crvena Zvezda, Image Name: fk-crvena-zvezda-1945-vector-logo-400x400.png
# Logo Name: PayPaltype, Image Name: paypal-logo-preview-400x400.png
# Logo Name: Oppo Electronics, Image Name: oppo-electronics-logo-vector-download-400x400.jpg
# Logo Name: MSI (Micro-Star International), Image Name: msi-vector-logo-400x400.png
# Logo Name: VW – GTI, Image Name: vw-gti-vector-logo-400x400.png
# Logo Name: Pink Panther, Image Name: pink-panther-vector-400x400.png
# Logo Name: CSL, Image Name: csl-vector-logo-400x400.png
# Logo Name: Freddie Mercury tribute, Image Name: freddie-mercury-tribute-logo-vector-400x400.png
# Logo Name: Volvo, Image Name: volvo-black-vector-logo-400x400.png
# Logo Name: Swastika, Image Name: swastika-logo-vector-400x400.jpg
# Logo Name: Maruti Suzuki, Image Name: maruti-suzuki-eps-vector-logo-400x400.png
# Logo Name: Puma Bodywear, Image Name: puma-bodywear-vector-logo-400x400.png
# Logo Name: Starbucks Coffee, Image Name: starbucks-coffee-black-vector-logo-400x400.png
# Logo Name: Adidas Trefoil, Image Name: Adidas-Trefoil-logo-vector-for-free-download.png
# Logo Name: DVD Easter Egg, Image Name: dvd-easter-egg-vector-logo-400x400.png
# Logo Name: Nestle, Image Name: nestle-eps-vector-logo-400x400.png
# Logo Name: Amazon.com, Image Name: amazon-logo-vector-download-400x400.jpg
# Logo Name: Kawasaki Ninja, Image Name: ninja-kawasaki-old-vector-logo-400x400.png
# Logo Name: NFL, Image Name: nfl-logo-National-Football-League-400x400.png
# Logo Name: Mack Trucks, Image Name: mack-trucks-vector-logo-400x400.png
# Logo Name: Wu-Tang Clan, Image Name: wu-tang-clan-vector-logo-400x400.png
# Logo Name: Everlast boxing, Image Name: everlast-boxing-logo-vector-400x400.png
# Logo Name: Kappa, Image Name: kappa-eps-vector-logo-400x400.png
# Logo Name: Melitta, Image Name: melitta-logo-preview-400x400.png
# Logo Name: Qatar World Cup 2022 Bid, Image Name: qatar-2022-logo-vector-01.png
# Logo Name: Audi, Image Name: audi-black-vector-logo-400x400.png
# Logo Name: Hellfish, Image Name: hellfish-vector-logo-400x400.png
# Logo Name: Carhartt, Image Name: carhartt-eps-vector-logo-400x400.png
# Logo Name: Brembo, Image Name: brembo-.eps-logo-vector-400x400.png
# Logo Name: AKRAPOVIC, Image Name: akrapovic-logo-vector-400x400.png
# Logo Name: Gulf Air, Image Name: gulf-air-logo-preview-400x400.png
# Logo Name: ITC Limited, Image Name: itc-limited-vector-logo-400x400.png
# Logo Name: Bose, Image Name: bose-logo-preview-400x400.png
# Logo Name: TRD, Image Name: trd-vector-logo-400x400.png
# Logo Name: Advan, Image Name: advan-logo-vector-download.jpg
# Logo Name: Roland, Image Name: roland-eps-vector-logo-400x400.png
# Logo Name: New England Patriots Wordmark, Image Name: new-england-patriots-logo-preview-400x400.png
# Logo Name: Fanta Orange, Image Name: fanta-orange-vector-logo-400x400.png
# Logo Name: Renault Lines, Image Name: renault-lines-vector-logo-400x400.png
# Logo Name: Muhammad, Image Name: muhammad-vector-logo-400x400.png
# Logo Name: Superman, Image Name: Superman-vector.png
# Logo Name: SSC Napoli, Image Name: ssc-napoli-vector-logo-400x400.png
# Logo Name: Diesel Only The Brave, Image Name: diesel-only-the-brave-vector-400x400.jpg
# Logo Name: Puma, Image Name: puma-eps-vector-logo-400x400.png
# Logo Name: SketchUp, Image Name: sketchup-vector-logo-400x400.png
# Logo Name: TRD Off Road, Image Name: trd-off-road-vector-logo-400x400.png
# Logo Name: Metallica Snake, Image Name: metallica-snake-vector-logo-400x400.png
# Logo Name: Dennis the Menace, Image Name: dennis-the-menace-eps-vector-400x400.png
# Logo Name: Fender Stratocaster, Image Name: fender-stratocaster-logo-vector-400x400.png
# Logo Name: Fox Moto, Image Name: fox-moto-logo-vector-400x400.png
# Logo Name: Herbalife Nutrition, Image Name: herbalife-nutrition-vector-logo-400x400.png
# Logo Name: Polo Ralph Lauren, Image Name: polo-ralph-lauren-logo-vector-400x400.png
# Logo Name: SKY, Image Name: sky-eps-vector-logo-400x400.png
# Logo Name: Mickey Mouse, Image Name: mickey-mouse-character-vector-400x400.png
# Logo Name: Fendi, Image Name: fendi-logo-vector.jpg
# Logo Name: The North Face, Image Name: the-north-face-eps-vector-logo-400x400.png
# Logo Name: Yandex, Image Name: yandex-logo-vector-download-400x400.jpg
# Logo Name: Scania, Image Name: scania-logo.png
# Logo Name: Ford, Image Name: ford-black-logo-vector-400x400.png
# Logo Name: Dropbox, Image Name: dropbox-logo-400x400.png
# Logo Name: Nutella, Image Name: nutella-company-vector-logo-400x400.png
# Logo Name: Man, Image Name: man-vector-logo-400x400.png
# Logo Name: TRD Sport, Image Name: trd-sport-vector-logo-400x400.png
# Logo Name: Johnnie Walker Black Label, Image Name: johnnie-walker-black-label-logo-vector-download-400x400.jpg
# Logo Name: Michael Jordan, Image Name: michael-jordan-eps-vector-logo-400x400.png
# Logo Name: Supra, Image Name: supra-vector-logo-400x400.png
# Logo Name: Sonatrach, Image Name: sonatrach-logo-400x400.png
# Logo Name: Pizza Hut, Image Name: pizza-hut-logo.png
# Logo Name: G4S, Image Name: g4s-logo-vector-400x400.png
# Logo Name: Allah cellacelaluhu, Image Name: allah-cellacelaluhu-vector-logo-400x400.png
# Logo Name: Ralliart auto, Image Name: ralliart-auto-vector-logo-400x400.png
# Logo Name: Kawasaki Team Racing, Image Name: kawasaki-team-racing-vector-logo-400x400.png
# Logo Name: Versace Medusa, Image Name: versace-medusa-vector-logo-400x400.png
# Logo Name: Amazon Alexa, Image Name: amazon-alexa-logo.png
# Logo Name: Origin Energy, Image Name: origin-energy-logo.png
# Logo Name: Fender, Image Name: fender-logo-vector-400x400.png
# Logo Name: Yamaha Black, Image Name: yamaha-black-vector-logo-400x400.png
# Logo Name: Marubeni Corporation, Image Name: Marubeni-logo-400x400.png
# Logo Name: Alpinestars, Image Name: alpinestars-eps-vector-logo-400x400.png
# Logo Name: Ekstraklasa, Image Name: Ekstraklasa-logo-400x400.png
# Logo Name: Dell, Image Name: dell-logo-preview-400x400.png
# Logo Name: Opel, Image Name: opel-2002-vector-logo-400x400.png
# Logo Name: Daewoo, Image Name: daewoo-eps-vector-logo-400x400.png
# Logo Name: Tommy Hilfiger, Image Name: tommy-hilfiger-logo-vector-01.png
# Logo Name: Shoei, Image Name: shoei-black-vector-logo-400x400.png
# Logo Name: XXX energy drink, Image Name: xxx-energy-drink-vector-logo-400x400.png
# Logo Name: British American Tobacco (BAT), Image Name: bat-logo-preview-400x400.png
# Logo Name: Spiderman, Image Name: spiderman-eps-vector-logo-400x400.png
# Logo Name: Google Photos, Image Name: google-photos-logo-vector-download-400x400.jpg
# Logo Name: Ferrero, Image Name: ferrero-vector-logo-400x400.png
# Logo Name: Ibanez, Image Name: ibanez-logo-vector-400x400.png
# Logo Name: NOS, Image Name: nos-eps-vector-logo-400x400.png
# Logo Name: Zalando, Image Name: zalando-logo-preview-400x400.png
# Logo Name: DC Shoes, Image Name: dc-shoes-logo-vector-400x400.png
# Logo Name: Prada, Image Name: prada-logo-vector-01.png
# Logo Name: Repsol, Image Name: repsol-logo-preview-400x400.png
# Logo Name: Ford emblem, Image Name: ford-emblem-logo-vector-400x400.png
# Logo Name: Polo Ralph Lauren, Image Name: polo-ralph-lauren-logo-vector-400x400.png
# Logo Name: Ajuntament de Barcelona, Image Name: ajuntament-de-barcelona-vector-logo-400x400.png
# Logo Name: Nirvana Nevermind, Image Name: nirvana-nevermind-vector-logo-400x400.png
# Logo Name: Converse Shoes, Image Name: converse-shoes-.eps-logo-vector-400x400.png
# Logo Name: Uniqlo, Image Name: Uniqlo-logo-400x400.png
# Logo Name: Lacoste, Image Name: lacoste-vector-400x400.jpg
# Logo Name: Ferrari World Abu Dhabi, Image Name: ferrari-world-logo.png
# Logo Name: Freelancer, Image Name: freelancer-logo-400x400.png
# Logo Name: Canon, Image Name: Canon-logo-400x400.png
# Logo Name: Bluetooth, Image Name: bluetooth-logo-vector-400x400.png
# Logo Name: Audi sport, Image Name: audi-sport-vector-logo-400x400.png
# Logo Name: Target, Image Name: target-logo-preview-400x400.png
# Logo Name: Minnie Mouse, Image Name: minnie-mouse-disney-vector-400x400.png
# Logo Name: Maruti Suzuki, Image Name: Maruti-Suzuki-logo-vector.png
# Logo Name: Toyota, Image Name: toyota-eps-vector-logo-400x400.png
# Logo Name: Volkswagen Group, Image Name: volkswagen-group-logo-vector-download-400x400.jpg
# Logo Name: STP, Image Name: stp-vector-logo-400x400.png
# Logo Name: Amsoil, Image Name: amsoil-vector-logo-400x400.png
# Logo Name: Hitachi, Image Name: hitachi-company-vector-logo-400x400.png
# Logo Name: Hitachi, Image Name: hitachi-company-vector-logo-400x400.png
# Logo Name: BMW M Series, Image Name: bmw-m-series-vector.gif
# Logo Name: Google Drive, Image Name: Google-Drive-logo-vector.png
# Logo Name: Amazon history, Image Name: amazon-logo-history-400x400.jpg
# Logo Name: Corsair, Image Name: corsair-logo-preview-400x400.png
# Logo Name: Cartier, Image Name: cartier-eps-vector-logo-400x400.png
# Logo Name: Danone, Image Name: danone-eps-vector-logo-400x400.png
# Logo Name: Dream Theater Hexagon, Image Name: dream-theater-hexagon-vector-logo-400x400.png
# Logo Name: Nestle Food, Image Name: nestle-food-vector-logo-400x400.png
# Logo Name: XXX TV, Image Name: xxx-tv-vector-logo-400x400.png
# Logo Name: Toyota Moto, Image Name: toyota-moto-vector-logo-400x400.png
# Logo Name: Twitch, Image Name: Twitch-logo-400x400.jpg
# Logo Name: Playboy, Image Name: Playboy-logo-vector-400x400.png
# Logo Name: Chrysler, Image Name: chrysler-.eps-logo-vector-400x400.png
# Logo Name: Sprite, Image Name: sprite-logo-vector-400x400.png
# Logo Name: Chivas Guadalajara, Image Name: chivas-guadalajara-vector-logo-400x400.png
# Logo Name: Two Brothers Racing, Image Name: two-brothers-racing-eps-vector-logo-400x400.png
# Logo Name: Starbucks, Image Name: starbucks-logo-vector-400x400.png
# Logo Name: Mercedes-Benz, Image Name: mercedes-benz-eps-vector-logo-400x400.png
# Logo Name: Toshiba, Image Name: toshiba-eps-vector-logo-400x400.png
# Logo Name: LinkedIn, Image Name: linkedin-black-logo.png
# Logo Name: NOFX, Image Name: nofx-vector-logo-400x400.png
# Logo Name: Honda Transalp, Image Name: honda-transalp-vector-logo-400x400.png
# Logo Name: Bullet For My Valentine, Image Name: bullet-for-my-valentine-eps-vector-logo-400x400.png
# Logo Name: Bombay Sapphire, Image Name: bombay-sapphire-logo-vector-400x400.png
# Logo Name: Dodge, Image Name: dodge-.eps-logo-vector-400x400.png
# Logo Name: Vingroup, Image Name: vingroup-logo-preview-400x400.png
# Logo Name: NFS Most Wanted, Image Name: nfs-most-wanted-vector-logo-400x400.png
# Logo Name: Batman, Image Name: batman-vector-free-download.png
# Logo Name: Michael Jackson, Image Name: michael-jackson-eps-vector-400x400.png
# Logo Name: Stihl, Image Name: stihl-company-vector-logo-400x400.png
# Logo Name: Android Pay, Image Name: android-pay-logo.png
# Logo Name: Microsoft Exchange, Image Name: microsoft-exchange-logo-vector-download-400x400.jpg
# Logo Name: Rolls-Royce, Image Name: rolls-royce-logo.png
# Logo Name: Harley-Davidson 1, Image Name: harley-davidson-1-vector-logo-400x400.png
# Logo Name: Puma SE, Image Name: puma-se-vector-logo-400x400.png
# Logo Name: Naruto, Image Name: naruto-vector-logo-400x400.png
# Logo Name: MasterCard, Image Name: mastercard-logo-400x400.png
# Logo Name: Volvo Cars, Image Name: volvo-cars-vector-logo-400x400.png
# Logo Name: OZ racing, Image Name: OZ-racing-logo-vector-free-download-01.png
# Logo Name: Pirelli, Image Name: pirelli-logo.png
# Logo Name: Escudo del Peru, Image Name: escudo-del-peru-logo-vector-400x400.png
# Logo Name: Google Maps, Image Name: new-google-maps-logo-vector-download-400x400.jpg
# Logo Name: Vietcombank, Image Name: vietcombank-vector-logo.png
# Logo Name: LG Electronics, Image Name: lg-electronics-vector-logo-400x400.png
# Logo Name: Jerry, Image Name: jerry-vector-logo-400x400.png
# Logo Name: Sprinter, Image Name: sprinter-vector-logo-400x400.png
# Logo Name: Petrovietnam, Image Name: petrovietnam-logo-vector-download-400x400.jpg
# Logo Name: SAP, Image Name: sap-logo-preview-400x400.png
# Logo Name: FC Midtjylland, Image Name: fc-midtjylland-vector-logo-400x400.png
# Logo Name: Gucci, Image Name: gucci-group-logo-vector-400x400.png
# Logo Name: Dubai International Airport, Image Name: dubai-international-airport-logo.png
# Logo Name: Hawaiian Airlines, Image Name: hawaiian-airlines-logo-01.png
# Logo Name: Converse Shoes, Image Name: converse-shoes-logo-vector-01.png
# Logo Name: Duke Energy, Image Name: duke-energy-logo.png
# Logo Name: Kansas City Chiefs, Image Name: kansas-city-chiefs-logo-vector-download-400x400.jpg
# Logo Name: K&N, Image Name: k-n-logo-vector-download-400x400.jpg
# Logo Name: Hyundai, Image Name: Hyundai-logo.png
# Logo Name: Visa US, Image Name: visa-us-vector-logo-400x400.png
# Logo Name: Mickey mouse & donald duck, Image Name: mickey-mouse-donald-duck-vector-logo-400x400.png
# Logo Name: PostNL, Image Name: postnl-logo-preview-400x400.png
# Logo Name: New UEFA Europa League, Image Name: uefa-europa-league-logo-preview-400x400.png
# Logo Name: Malindo Air, Image Name: malindo-air-vector-logo-400x400.png
# Logo Name: Xerox, Image Name: xerox-eps-vector-logo-400x400.png
# Logo Name: Ramones, Image Name: ramones-vector-logo-400x400.png
# Logo Name: Instagram icon, Image Name: instagram-icon-vector-logo-400x400.png
# Logo Name: Manchester City, Image Name: manchester-city-logo.png
# Logo Name: Barbie, Image Name: barbie-logo-vector-01.png
# Logo Name: Wayfair, Image Name: wayfair-logo.png
# Logo Name: Pajero Sport, Image Name: pajero-sport-vector-logo-400x400.png
# Logo Name: Toyota Rav4, Image Name: rav4-vector-logo-400x400.png
# Logo Name: Lambretta, Image Name: lambretta-vector-logo-400x400.png
# Logo Name: He-Man & She-Ra, Image Name: he-man-she-ra-vector-400x400.png
# Logo Name: Playboy Bunny, Image Name: playboy-bunny-vector-logo-400x400.png
# Logo Name: Vaillant, Image Name: vaillant-vector-logo-400x400.png
# Logo Name: Shell, Image Name: shell-logo-400x400.png
# Logo Name: Cruzeiro Esporte Clube, Image Name: cruzeiro-esporte-clube-logo-vector-400x400.png
# Logo Name: Starbucks Coffee, Image Name: starbucks-coffee-logo-preview-400x400.png
# Logo Name: Iron Maiden Eddie Smile, Image Name: iron-maiden-eddie-smile-vector-logo-400x400.png
# Logo Name: Available on the App Store badge, Image Name: available-on-the-app-store-badge-logo-vector-400x400.png
# Logo Name: MKS Odra Wodzislaw Slaski SA, Image Name: mks-odra-wodzislaw-slaski-sa-vector-logo-400x400.png
# Logo Name: TOOL Lateralus Eye, Image Name: tool-lateralus-eye-vector-logo-400x400.png
# Logo Name: UEFA Europa League, Image Name: uefa-europa-league-logo-vector-download-400x400.jpg
# Logo Name: Hermes International, Image Name: hermes-international-vector-logo-400x400.png
# Logo Name: Arsenal FC, Image Name: Arsenal-vector-logo-download-400x400.jpg
# Logo Name: Lotte, Image Name: lotte-Logo-Vector-Download-400x400.jpg
# Logo Name: Flipkart, Image Name: flipkart-logo-vector-download-400x400.jpg
# Logo Name: GoPro, Image Name: gopro-logo-vector-download-400x400.jpg
# Logo Name: Mazda Car, Image Name: mazda-car-vector-logo-400x400.png
# Logo Name: Big Lots, Image Name: big-lots-logo.png
# Logo Name: PLKS Pewel Mala, Image Name: plks-pewel-mala-vector-logo-400x400.png
# Logo Name: IKEA, Image Name: ikea-black-vector-logo-400x400.png
# Logo Name: Yahoo, Image Name: Yahoo-logo-vector-download-400x400.jpg
# Logo Name: Zippo, Image Name: zippo-logo-01.png
# Logo Name: Venom, Image Name: venom-vector-400x400.png
# Logo Name: Feyenoord Rotterdam, Image Name: feyenoord-rotterdam-1908-vector-logo-400x400.png
# Logo Name: Arkie Toys, Image Name: arkie-toys-logo-vector-download.jpg
# Logo Name: Skype, Image Name: skype-logo.png
# Logo Name: Agoda, Image Name: agoda-logo-preview-400x400.png
# Logo Name: Behance, Image Name: behance-logo-vector-download-400x400.jpg
# Logo Name: Facebook, Image Name: facebook-icon-logo-vector-400x400.png
# Logo Name: Subaru, Image Name: subaru-old-vector-logo-400x400.png
# Logo Name: Vinamilk, Image Name: vinamilk-logo-vector-download-400x400.jpg
# Logo Name: Playboy Magazine, Image Name: playboy-magazine-vector-logo-400x400.png
# Logo Name: Barclays Premier League, Image Name: barclays-premier-league-logo-preview-400x400.png
# Logo Name: Apple 3D, Image Name: apple-3d-vector-logo-400x400.png
# Logo Name: Queen, Image Name: queen-music-band-vector-logo-400x400.png
# Logo Name: Game Of Thrones, Image Name: game-of-thrones-logo.png
# Logo Name: Moschino, Image Name: moschino-vector-logo-400x400.png
# Logo Name: Toyota Etios, Image Name: toyota-etios-vector-logo-400x400.png
# Logo Name: HP, Image Name: hp-logo-vector-download-400x400.jpg
# Logo Name: Kenzo, Image Name: kenzo-vector-logo-400x400.png
# Logo Name: Nirvana, Image Name: nirvana-band-vector-logo-400x400.png
# Logo Name: Amway, Image Name: amway-vector-logo-400x400.png
# Logo Name: AVG AntiVirus, Image Name: avg-antivirus-logo-400x400.png
# Logo Name: Meizu, Image Name: meizu-logo.png
# Logo Name: KP Chemik Police, Image Name: kp-chemik-police-vector-logo-400x400.png
# Logo Name: Queen Hot Space, Image Name: queen-hot-space-vector-logo-400x400.png
# Logo Name: LG, Image Name: lg-lifes-good-logo-400x400.png
# Logo Name: Carl’s Jr., Image Name: carls-jr-logo-01.png
# Logo Name: Milo, Image Name: milo-vector-logo-400x400.png
# Logo Name: Harley-Davidson, Image Name: harley-davidson-logo.png
# Logo Name: Claro PB, Image Name: claro-pb-logo-vector-400x400.png
# Logo Name: Jollibee, Image Name: jollibee-vector-logo-400x400.png
# Logo Name: China Southern Airlines, Image Name: china-southern-airlines-logo-vector-download-400x400.jpg
# Logo Name: Dacia, Image Name: dacia-logo-vector-01.png
# Logo Name: Independent, Image Name: independent-vector-logo-400x400.png
# Logo Name: Honda Varadero, Image Name: honda-varadero-vector-logo-400x400.png
# Logo Name: Ferrari, Image Name: Ferrari-logo-vector.png
# Logo Name: CIMB Bank Reversed, Image Name: cimb-bank-reversed-logo-vector-400x400.png
# Logo Name: SV Linx 1949, Image Name: sv-linx-1949-vector-logo-400x400.png
# Logo Name: FC UTA Arad, Image Name: fc-uta-arad-vector-logo-400x400.png
# Logo Name: Lacoste, Image Name: lacoste-eps-vector-logo-400x400.png
# Logo Name: Congress, Image Name: congress-logo-vector-400x400.png
# Logo Name: Twitter, Image Name: twitter-logo.png
# Logo Name: Deezer, Image Name: deezer-vector-logo-400x400.png
# Logo Name: The Pokémon Company, Image Name: pokmon-company-vector-logo-400x400.png
# Logo Name: Waze, Image Name: waze-vector-logo-400x400.png
# Logo Name: KTM Racing, Image Name: ktm-racing-vector-400x400.jpg
# Logo Name: Victoria Bitter – VB, Image Name: victoria-bitter-vb-vector-logo-400x400.png
# Logo Name: VW Golf, Image Name: vw-golf-vector-logo-400x400.png
# ...
# Logo Name: Philadelphia Phillies, Image Name: Philadelphia-Phillies-logo-400x400.png
# Logo Name: Dailymotion, Image Name: dailymotion-logo.png
# Logo Name: Upwork, Image Name: upwork-logo.png
# Logo Name: Nike, Image Name: nike-clothing-vector-logo-400x400.png
# Logo Name: Sydney FC, Image Name: sydney-fc-logo.png
# Logo Name: RTP (Rádio e Televisão de Portugal), Image Name: rtp-logo-vector-download-400x400.jpg
# Logo Name: SembCorp, Image Name: sembcorp-logo-vector-download.jpg
# Logo Name: Everton F.C., Image Name: everton-fc-logo-preview-400x400.png
# Logo Name: Old McDonald, Image Name: old-mcdonalds-vector-logo-400x400.png
# Logo Name: Shelby, Image Name: shelby-vector-logo-400x400.png
# Logo Name: Wilson, Image Name: wilson-logo-vector-01.png
# Logo Name: Izmir bbybkeehir belediyesi, Image Name: izmir-bbybkeehir-belediyesi-vector-logo-400x400.png
# Logo Name: Atari, Image Name: atari-games-black-logo-vector-download.jpg
# Logo Name: HRS, Image Name: hrs-logo.png
# Logo Name: Pizza Hut, Image Name: pizza-hut-vector-logo-400x400.png
# Logo Name: Santander, Image Name: santander-vector-logo-400x400.png
# Logo Name: Maltese Cross, Image Name: maltese-cross-vector-logo-400x400.png
# Logo Name: Black Sabbath, Image Name: black-sabbath-arts-logo-vector-400x400.png
# Logo Name: Aprilia lion Variation 01, Image Name: aprilia-lion-variation-01-vector-logo-400x400.png
# Logo Name: Sun Life Financial, Image Name: sun-life-financial-logo-preview-400x400.png
# Logo Name: Midea, Image Name: midea-vector-logo-400x400.png
# Logo Name: Playboy, Image Name: playboy-logo-vector.jpg
# Logo Name: Kia Motors Coporation, Image Name: kia-motors-coporation-vector-logo-400x400.png
# Logo Name: Los Angeles Lakers, Image Name: los-angeles-lakers-logo-vector-400x400.png
# Logo Name: Overkill, Image Name: overkill-band-vector-logo-400x400.png
# Logo Name: Tod’s, Image Name: tods-vector-logo-400x400.png
# Logo Name: Tod’s Group, Image Name: tods-group-vector-logo-400x400.png
# Logo Name: Nintendo DS, Image Name: nintendo-ds-vector-logo-400x400.png
# Logo Name: P&G (Procter & Gamble), Image Name: pg-logo-vector.png
# Logo Name: Estado de Mexico – Compromiso, Image Name: estado-de-mexico-compromiso-logo-vector-400x400.png
# Logo Name: La Catrina, Image Name: la-catrina-vector-logo-400x400.png
# Logo Name: Sgt. Peppers Lonely Hearts Club Band, Image Name: sgt-peppers-lonely-hearts-club-band-vector-logo-400x400.png
# Logo Name: Rocket Internet, Image Name: rocket-internet-logo-01.png
# Logo Name: Metal Mulisha Moto, Image Name: metal-mulisha-moto-vector-logo-400x400.png
# Logo Name: Zaxby’s, Image Name: zaxbys-vector-logo-400x400.png
# Logo Name: Deftones, Image Name: deftones-logo-vector-400x400.png
# Logo Name: Sephora, Image Name: sephora-logo-vector-400x400.png
# Logo Name: Boavista FC, Image Name: boavista-fc-vector-logo-400x400.png
# Logo Name: Wilson, Image Name: wilson-logo-400x400.png
# Logo Name: Linkin Park, Image Name: linkin-park-band-vector-logo1-400x400.png
# Logo Name: Asterix, Obelix & Idefix, Image Name: asterix-obelix-idefix-vector-400x400.png
# Logo Name: Hello Kitty, Image Name: hello-kitty-only-text-vector-logo-400x400.png
# Logo Name: UPAEP, Image Name: upaep-vector-logo-400x400.png
# Logo Name: Jeep, Image Name: jeep-black-vector-logo-400x400.png
# Logo Name: flydubai, Image Name: flydubai-logo.png
# Logo Name: Atlanta Braves, Image Name: Atlanta-Braves-logo-vector-download-400x400.png
# Logo Name: West Coast Customs, Image Name: west-coast-customs-vector-logo-400x400.png
# Logo Name: Cartman, Image Name: cartman-vector-400x400.png
# Logo Name: Repsol, Image Name: repsol-vector-logo-400x400.png
# Logo Name: Foster’s, Image Name: Fosters-logo-vector-download-400x400.jpg
# Logo Name: Bettys, Image Name: bettys-logo-preview-400x400.png
# Logo Name: ThinkPad, Image Name: thinkpad-logo-vector-download-400x400.jpg
# Logo Name: Middlesbrough FC, Image Name: middlesbrough-fc-logo-preview-400x400.png
# Logo Name: Total S.A, Image Name: total-s.a-logo-vector-01.png
# Logo Name: Wall-E, Image Name: wall-e-vector-logo-400x400.png
# Logo Name: Matrix, Image Name: matrix-vector-logo-400x400.png
# Logo Name: Borders, Image Name: borders-vector-logo-400x400.png
# Logo Name: FILA, Image Name: fila-logo-vector-01.png
# Logo Name: Tommy Hilfiger, Image Name: tommy-hilfiger-eps-vector-logo-400x400.png
# Logo Name: Ecko Unlimited, Image Name: ecko-unlimited-.eps-logo-vector-400x400.png
# Logo Name: Sempra Energy, Image Name: sempra-energy-logo-vector-download-400x400.jpg
# Logo Name: Credit Suisse, Image Name: credit-suisse-logo-vector-download-400x400.jpg
# Logo Name: CAF Confederation Cup, Image Name: caf-confederation-cup-vector-logo-400x400.png
# Logo Name: Barbie, Image Name: barbie-logo-vector-400x400.png
# Logo Name: Nestlé, Image Name: nestl-logo-vector-download-400x400.jpg
# Logo Name: Vespa Moto, Image Name: vespa-moto-vector-logo-400x400.png
# Logo Name: Omnicom Group, Image Name: omnicom-logo-vector-download-400x400.jpg
# Logo Name: Yahoo Mail, Image Name: yahoo-mail-vector-logo-400x400.png
# Logo Name: Knauf, Image Name: knauf-vector-logo-400x400.png
# Logo Name: Dachdecker Innung, Image Name: dachdecker-innung-logo-vector-400x400.png
# Logo Name: Hitachi, Image Name: hitachi-logo-download-400x400.png
# Logo Name: Knauf, Image Name: knauf-vector-logo-400x400.png
# Logo Name: Tribal, Image Name: tribal-eps-vector-logo-400x400.png
# Logo Name: Volkswagen Auto, Image Name: volkswagen-auto-eps-vector-logo-400x400.png
# Logo Name: KISS band, Image Name: kiss-band-vector-logo-400x400.png
# Logo Name: Sony Corporation, Image Name: sony-corporation-vector-logo-400x400.png
# Logo Name: The Incredibles, Image Name: the-incredibles-eps-vector-400x400.png
# Logo Name: Black & Decker, Image Name: black-decker-eps-vector-logo-400x400.png
# Logo Name: WePay, Image Name: wepay-logo.png
# Logo Name: Movistar Pharma, Image Name: movistar-pharma-vector-logo1-400x400.png
# Logo Name: Vejle Boldklub, Image Name: vejle-boldklub-vector-logo-400x400.png
# Logo Name: Chevy Chisiled With Flames, Image Name: chevy-chisiled-with-flames-logo-vector-400x400.png
# Logo Name: jQuery, Image Name: jquery-logo-vector-download-400x400.jpg
# Logo Name: Ozzy Osbourne, Image Name: ozzy-osbourne-vector-logo-400x400.png
# Logo Name: Southwest Airlines, Image Name: southwest-airlines-logo-vector-01.png
# Logo Name: InfoCenter Lan House e Cyber Cafe, Image Name: infocenter-lan-house-e-cyber-cafe-vector-logo-400x400.png
# Logo Name: Airwell, Image Name: airwell-logo-preview-400x400.png
# Logo Name: Burger King, Image Name: burger-king-vector-400x400.jpg
# Logo Name: Hamilton Tiger-Cats, Image Name: hamilton-tiger-cats-vector-logo-400x400.png
# Logo Name: KS Widzew Lodz, Image Name: ks-widzew-lodz-vector-logo-400x400.png
# Logo Name: Honda Dominator, Image Name: honda-dominator-vector-logo-400x400.png
# Logo Name: Los Angeles Dodgers, Image Name: los-angeles-dodgers-logo.png
# Logo Name: Lamborghini, Image Name: lamborghini-eps-vector-logo-400x400.png
# Logo Name: USB, Image Name: usb-eps-vector-logo-400x400.png
# Logo Name: Wilson, Image Name: wilson-black-vector-logo-400x400.png
# Logo Name: Initial D, Image Name: initial-d-vector-logo-400x400.png
# Logo Name: Mickey Mouse, Image Name: mickey-mouse-icons-vector-400x400.png
# Logo Name: Bose, Image Name: bose-logo-vector-400x400.png
# Logo Name: Shark Energy Drink, Image Name: shark-energy-drink-vector-logo-400x400.png
# Logo Name: Chopard, Image Name: chopard-vector-logo-400x400.png
# Logo Name: Justitia, Image Name: justitia-vector-logo-400x400.png
# Logo Name: Tecate Light, Image Name: tecate-light-vector-logo-400x400.png
# Logo Name: Coach Black, Image Name: coach-black-vector-logo-400x400.png
# Logo Name: Jetstar, Image Name: jetstar-2012-vector-logo-400x400.png
# Logo Name: Razertype, Image Name: razer-logotype-eps-400x400.png
# Logo Name: Adobe Systems, Image Name: adobe-systems-vector-logo-400x400.png
# Logo Name: Umbro, Image Name: umbro-black-vector-logo-400x400.png
# Logo Name: Nintendo, Image Name: nintendo-vector-logo-400x400.png
# Logo Name: Pirelli, Image Name: pirelli-black-vector-logo-400x400.png
# Logo Name: RoHS tested, Image Name: rohs-tested-logo-vector-400x400.png
# Logo Name: Art-Corel-Draw-12, Image Name: art-corel-draw-12-vector-logo-400x400.png
# Logo Name: Haribo boy, Image Name: haribo-boy-vector-logo-400x400.png
# Logo Name: Dell, Image Name: dell-3d-logo-vector-01.png
# Logo Name: Opel Old, Image Name: opel-old-vector-logo-400x400.png
# Logo Name: Nivea, Image Name: nivea-black-vector-logo-400x400.png
# Logo Name: Mercedes-Benz – MB, Image Name: mercedes-benz-mb-vector-logo-400x400.png
# Logo Name: Nike Football, Image Name: nike-football-vector-logo-400x400.png
# Logo Name: Wesfarmers, Image Name: wesfarmers-logo.png
# Logo Name: Ford, Image Name: ford-logo-vector-01.png
# Logo Name: Gant, Image Name: gant-logo-vector-400x400.png
# Logo Name: Gigabyte Technology, Image Name: gigabyte-technology-logo-vector-400x400.png
# Logo Name: Trafik Polisi, Image Name: trafik-polisi-vector-logo-400x400.png
# Logo Name: Baby Pooh, Image Name: baby-pooh-logo-vector-400x400.png
# Logo Name: Mazda Motor Corporation, Image Name: mazda-motor-corporation-vector-logo-400x400.png
# Logo Name: Eibach Springs, Image Name: eibach-springs-.eps-logo-vector-400x400.png
# Logo Name: NASA, Image Name: nasa-eps-vector-logo-400x400.png
# Logo Name: Pizza Hut, Image Name: pizza-hut-eps-vector-logo-400x400.png
# Logo Name: CIMB Bank, Image Name: cimb-bank-logo-vector-400x400.png
# Logo Name: All Blacks, Image Name: all-blacks-eps-vector-logo-400x400.png
# Logo Name: Aral, Image Name: aral-black-vector-logo-400x400.png
# Logo Name: Danzig Skull, Image Name: danzig-skull-logo-vector-400x400.png
# Logo Name: Yamaha YZF, Image Name: yamaha-yzf-vector-logo-400x400.png
# Logo Name: Calvin Klein Watches, Image Name: calvin-klein-watches-logo-vector-400x400.png
# Logo Name: FedEx Office, Image Name: fedex-office-logo-vector-download-400x400.jpg
# Logo Name: Scania Aktiebolag, Image Name: scania-aktiebolag-vector-logo-400x400.png
# Logo Name: Nike Golf, Image Name: nike-golf-vector-logo-400x400.png
# Logo Name: Toyota Racing Division, Image Name: toyota-racing-division-vector-logo-400x400.png
# Logo Name: Nissin, Image Name: nissin-vector-logo-400x400.png
# Logo Name: KV Mechelen, Image Name: kv-mechelen-vector-logo-400x400.png
# Logo Name: Nike Football, Image Name: nike-football-eps-vector-logo-400x400.png
# Logo Name: Behringer, Image Name: behringer-vector-logo-400x400.png
# Logo Name: Iron Man, Image Name: iron-man-vector-400x400.png
# Logo Name: Trussardi, Image Name: trussardi-vector-logo-400x400.png
# Logo Name: Nike Plus, Image Name: nike-plus-vector-logo-400x400.png
# Logo Name: Meetup, Image Name: meetup-logo-400x400.png
# Logo Name: Yamaha MT-01, Image Name: yamaha-mt-01-vector-logo-400x400.png
# Logo Name: Google Plus, Image Name: google-plus-logo.png
# Logo Name: Ariston, Image Name: ariston-black-logo-vector-download.jpg
# Logo Name: Dethleffs, Image Name: dethleffs-vector-logo-400x400.png
# Logo Name: Super Mario Bros., Image Name: super-mario-bros-vector-logo-400x400.png
# Logo Name: Moncler, Image Name: moncler-vector-logo-400x400.png
# Logo Name: Playboy, Image Name: playboy-tv-eps-vector-logo-400x400.png
# Logo Name: No Fear, Image Name: no-fear-eps-vector-logo-400x400.png
# Logo Name: Visa Inc, Image Name: visa-inc-vector-logo-400x400.png
# Logo Name: Python, Image Name: python-logo-vector-400x400.png
# Logo Name: Panther, Image Name: panther-vector-logo-400x400.png
# Logo Name: Senati, Image Name: senati-vector-logo-400x400.png
# Logo Name: Levi’s, Image Name: levis-clothing-vector-logo-400x400.png
# Logo Name: AC Pisa 1909, Image Name: ac-pisa-1909-vector-logo-400x400.png
# Logo Name: Lufthansa, Image Name: lufthansa-logo-vector-400x400.png
# Logo Name: Zendesk, Image Name: zendesk-logo-vector-download-400x400.jpg
# Logo Name: Indian Oil Corporation, Image Name: indian-oil-corporation-vector-logo-400x400.png
# Logo Name: Kohl’s, Image Name: kohls-logo-vector-400x400.png
# Logo Name: Ben & Jerry’s, Image Name: ben-jerrys-vector-logo-400x400.png
# Logo Name: Stussy, Image Name: stussy-vector-logo-400x400.png
# Logo Name: Jack Daniel’s, Image Name: jack-daniel-vector-400x400.png
# Logo Name: Modena FC, Image Name: modena-fc-vector-logo-400x400.png
# Logo Name: KFC New, Image Name: kfc-new-vector-400x400.jpg
# Logo Name: Aareal Bank, Image Name: aareal-bank-vector-logo-400x400.png
# Logo Name: Scania black, Image Name: scania-black-vector-logo-400x400.png
# Logo Name: F.N.B. bank, Image Name: fnb-bank-vector-logo-400x400.png
# Logo Name: Singer, Image Name: singer-vector-logo-400x400.png
# Logo Name: Renault 2004, Image Name: renault-2004-vector-logo-400x400.png
# Logo Name: Houzz, Image Name: houzz-logo.png
# Logo Name: Vaillant, Image Name: vaillant-eps-vector-logo-400x400.png
# Logo Name: Johnnie walker, Image Name: johnnie-walker-logo-vector1-400x400.png
# Logo Name: Joico, Image Name: joico-vector-logo-400x400.png
# Logo Name: Mickey Mouse, Image Name: mickey-mouse-12-pictures-vector-400x400.png
# Logo Name: Hot Wheels Art, Image Name: hot-wheels-art-vector-logo-400x400.png
# Logo Name: Citroen Transport, Image Name: citroen-transport-logo-vector-400x400.png
# Logo Name: Jata Negeri Kelantan, Image Name: jata-negeri-kelantan-vector-logo-400x400.png
# Logo Name: Hamilton Tiger-Cats team, Image Name: hamilton-tiger-cats-team-vector-logo-400x400.png
# Logo Name: Constant Contact, Image Name: constant-contact-logo.png
# Logo Name: Nintendo Direct, Image Name: nintendo-direct-logo.png
# Logo Name: EBay, Image Name: ebay-logo-vector-download-400x400.jpg
# Logo Name: Tokyo 2020 Olympic, Image Name: tokyo-2020-olympic-logo.png
# Logo Name: Wells Fargo, Image Name: wells-fargo-logo-preview-400x400.png
# Logo Name: Peugeot, Image Name: peugeot-car-vector-logo-400x400.png
# Logo Name: Xplod Sony, Image Name: xplod-sony-vector-logo-400x400.png
# Logo Name: Adidas celebrate originality, Image Name: adidas-celebrate-originality-vector-logo-400x400.png
# Logo Name: Boca Juniors 1920, Image Name: boca-juniors-1920-vector-logo-400x400.png
# Logo Name: Arnette, Image Name: arnette-vector-logo-400x400.png
# Logo Name: Mapa del ecuador, Image Name: mapa-del-ecuador-vector-logo-400x400.png
# Logo Name: Maybelline, Image Name: maybelline-vector-logo-400x400.png
# Logo Name: TSV 1860 Munchen, Image Name: tsv-1860-munchen-vector-logo-400x400.png
# Logo Name: Toyota Camry, Image Name: toyota-camry-logo-vector-01-400x400.png
# Logo Name: Olam, Image Name: olam-logo-vector-download-400x400.jpg
# Logo Name: Jagermeister, Image Name: jagermeister-eps-vector-logo-400x400.png
# Logo Name: ASUS, Image Name: asus-logo-vector-400x400.png
# Logo Name: VW Motorsport, Image Name: vw-motorsport-vector-logo-400x400.png
# Logo Name: Manchester United, Image Name: manchester-united-logo-vector-400x400.png
# Logo Name: Barclays, Image Name: Barclays-bank-logo-vector-free-download.png
# Logo Name: LLB, Image Name: llb-vector-logo-400x400.png
# Logo Name: Zurich Insurance, Image Name: zurich-eps-vector-logo-400x400.png
# Logo Name: Eni, Image Name: eni-logo.png
# Logo Name: IEEE, Image Name: ieee-vector-logo-400x400.png
# Logo Name: Mustang Ford, Image Name: mustang-ford-vector-logo-400x400.png
# Logo Name: FIAT 500, Image Name: fiat-500-logo-vector-400x400.png
# Logo Name: Dogs Trust, Image Name: dogs-trust-vector-logo-400x400.png
# Logo Name: James Bond (007), Image Name: james-bond-007-vector-logo1-400x400.png
# Logo Name: Naver, Image Name: naver-logo-preview-400x400.png
# Logo Name: Inca Kola, Image Name: inca-kola-vector-logo-400x400.png
# Logo Name: MSV Duisburg, Image Name: msv-duisburg-1902-vector-logo-400x400.png
# Logo Name: Turkiye Seyahat Acentalari Birligi, Image Name: turkiye-seyahat-acentalari-birligi-vector-logo-400x400.png
# Logo Name: LA Clippers, Image Name: la-clippers-logo-preview-400x400.png
# Logo Name: Fanta Apelsin, Image Name: fanta-apelsin-vector-logo-400x400.png
# Logo Name: Zurich Insurance Group, Image Name: zurich-insurance-group-logo-preview-400x400.png
# Logo Name: Bosch, Image Name: bosch-.eps-logo-vector-400x400.png
# Logo Name: Ferrero Rocher Chocolate, Image Name: ferrero-rocher-chocolate-vector-logo-400x400.png
# Logo Name: FC Hoyvik, Image Name: fc-hoyvik-vector-logo-400x400.png
